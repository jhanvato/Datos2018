# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# # Carga de los dataframe

# %%
#nivel educativo
postulantes_educacion = pd.read_csv("datos/datos_navent_fiuba/fiuba_1_postulantes_educacion.csv", low_memory=False)

#fecha de nacimiento y genero
postulantes_genero_y_edad = pd.read_csv("datos/datos_navent_fiuba/fiuba_2_postulantes_genero_y_edad.csv", low_memory=False)

#vistas de avisos online y offline
vistas = pd.read_csv("datos/datos_navent_fiuba/fiuba_3_vistas.csv", low_memory=False)

#postulaciones hasta el 1ro de marzo 2018
postulaciones = pd.read_csv("datos/datos_navent_fiuba/fiuba_4_postulaciones.csv", low_memory=False)

#avisos online al 8 de marzo de 2018
avisos_online = pd.read_csv("datos/datos_navent_fiuba/fiuba_5_avisos_online.csv", low_memory=False)

#detalle de avisos vistos y postulados tanto offline como online
avisos_detalle = pd.read_csv("datos/datos_navent_fiuba/fiuba_6_avisos_detalle.csv", low_memory=False)

# %% [markdown]
# # Columnas

# %%
postulantes_educacion.columns
# Out:
# Index(['idpostulante', 'nombre', 'estado'], dtype='object')

# %%
postulantes_genero_y_edad.columns
# Out:
# Index(['idpostulante', 'fechanacimiento', 'sexo'], dtype='object')

# %%
vistas.columns
# Out:
# Index(['idAviso', 'timestamp', 'idpostulante'], dtype='object')

# %%
postulaciones.columns
# Out:
# Index(['idaviso', 'idpostulante', 'fechapostulacion'], dtype='object')

# %%
avisos_online.columns
# Out:
# Index(['idaviso'], dtype='object')

# %%
avisos_detalle.columns
# Out:
# Index(['idaviso', 'idpais', 'titulo', 'descripcion', 'nombre_zona', 'ciudad',
#        'mapacalle', 'tipo_de_trabajo', 'nivel_laboral', 'nombre_area',
#        'denominacion_empresa'],
#       dtype='object')

# %% [markdown]
# # informacion de columnas

# %%
postulantes_educacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298231 entries, 0 to 298230
# Data columns (total 3 columns):
# idpostulante    298231 non-null object
# nombre          298231 non-null object
# estado          298231 non-null object
# dtypes: object(3)
# memory usage: 6.8+ MB

# %%
postulantes_genero_y_edad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200888 entries, 0 to 200887
# Data columns (total 3 columns):
# idpostulante       200888 non-null object
# fechanacimiento    196138 non-null object
# sexo               200888 non-null object
# dtypes: object(3)
# memory usage: 4.6+ MB

# %%
vistas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961897 entries, 0 to 961896
# Data columns (total 3 columns):
# idAviso         961897 non-null int64
# timestamp       961897 non-null object
# idpostulante    961897 non-null object
# dtypes: int64(1), object(2)
# memory usage: 22.0+ MB

# %%
postulaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401623 entries, 0 to 3401622
# Data columns (total 3 columns):
# idaviso             int64
# idpostulante        object
# fechapostulacion    object
# dtypes: int64(1), object(2)
# memory usage: 77.9+ MB

# %%
avisos_online.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5028 entries, 0 to 5027
# Data columns (total 1 columns):
# idaviso    5028 non-null int64
# dtypes: int64(1)
# memory usage: 39.4 KB

# %%
avisos_detalle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13534 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13534 non-null int64
# idpais                  13534 non-null int64
# titulo                  13534 non-null object
# descripcion             13534 non-null object
# nombre_zona             13534 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13534 non-null object
# nivel_laboral           13534 non-null object
# nombre_area             13534 non-null object
# denominacion_empresa    13529 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# #  dataframe

# %%
postulantes_educacion.head()
# Out:
#   idpostulante         nombre    estado
# 0         NdJl       Posgrado  En Curso
# 1         8BkL  Universitario  En Curso
# 2         1d2B  Universitario  En Curso
# 3         NPBx  Universitario  En Curso
# 4         NPBx         Master  En Curso

# %%
postulantes_genero_y_edad.head()
# Out:
#   idpostulante fechanacimiento  sexo
# 0         NM5M      1970-12-03   FEM
# 1         5awk      1962-12-04   FEM
# 2         ZaO5      1978-08-10   FEM
# 3         NdJl      1969-05-09  MASC
# 4         eo2p      1981-02-16  MASC

# %%
vistas.head()
# Out:
#       idAviso                     timestamp idpostulante
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante     fechapostulacion
# 0  1112257047         NM5M  2018-01-15 16:22:34
# 1  1111920714         NM5M  2018-02-06 09:04:50
# 2  1112346945         NM5M  2018-02-22 09:04:47
# 3  1112345547         NM5M  2018-02-22 09:04:59
# 4  1112237522         5awk  2018-01-25 18:55:03

# %%
avisos_online.head()
# Out:
#       idaviso
# 0  1112355872
# 1  1112335374
# 2  1112374842
# 3  1111984070
# 4  1111822480

# %%
avisos_detalle.head(30)
# Out:
#        idaviso  idpais                                             titulo  \
# 0      8725750       1                   VENDEDOR/A PROVINCIA DE SANTA FE
# 1     17903700       1                                         Enfermeras
# 2   1000150677       1                                     Chofer de taxi
# 3   1000610287       1      CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4   1000872556       1      Operarios de Planta - Rubro Electrodomésticos
# 5   1001135716       1      Vendedor Viajante TUCUMAN/SANTIAGO DEL ESTERO
# 6   1001326344       1           Vendedor Viajante RECONQUISTA/AVELLANEDA
# 7   1001455648       1            Vendedor Viajante PILAR / ESCOBAR/TIGRE
# 8      9240880       1  Productores Asesores Independiente, para venta...
# 9   1001202662       1                              promotor/a , asesor/a
# 10  1001724563       1                                         Paramédico
# 11  1002181678       1                 Vendedor Viajante TIERRA DEL FUEGO
# 12  1002308544       1   Preventistas Importante Distribuidora de Bebidas
# 13  1002377536       1  Personal con experiencia en lavandería  para H...
# 14  1002448818       1                           Ejecutivo de Cuentas Sr.
# 15  1002511855       1                                Ingeniero Electrico
# 16  1110319893       1                Vendedores Telefónicos (Part- time)
# 17  1110383223       1  Vendedor Viajante ADROGUE/LANUS/AVELLANEDA/LOM...
# 18  1110386791       1                        Analista de Demand Planning
# 19  1110185164       1                        Administrativo de Recepción
# 20  1110322236       1                                  Analista Contable
# 21  1110513885       1    Distribuidor domiciliario con moto (SAN MIGUEL)
# 22  1110322853       1            OPERADOR para Centro Operaciones de Red
# 23  1110640369       1                     VENDEDORES DE PLANES DE AHORRO
# 24  1110640622       1  Agente Inmobiliario para Oficinas RE/MAX en Zo...
# 25  1110706074       1         TECNICO SSr.  -Soporte a usuarios nivel 2-
# 26  1110711023       1   ENVASADOR / PREPARADOR / CONTROLADOR / EMBALADOR
# 27  1110715814       1                      Jefe de Calidad con movilidad
# 28  1110843329       1                                Chofer para Reparto
# 29  1110906170       1         SUPERVISOR COMODORO RIVADAVIA/BAHIA BLANCA
#
#                                           descripcion        nombre_zona  \
# 0   <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1   <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2   <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3   <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4   <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
# 5   <p>Somos una empresa multinacional que opera e...  Gran Buenos Aires
# 6   <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 7   <p>Somos una empresa multinacional que opera e...  Gran Buenos Aires
# 8   Agente\r\noficial Selecciona:</span></strong><...    Capital Federal
# 9   <p>En Cerantola nos encontramos en la busqueda...  Gran Buenos Aires
# 10  <p>Nos encontramos en un proceso de selección ...  Gran Buenos Aires
# 11  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 12  <p>YAMANIL S-A . se encuentra en busqueda de p...  Gran Buenos Aires
# 13  <p><strong><span lang="ES">Adecco Hoteles y Ca...  Gran Buenos Aires
# 14  <p>Importante empresa del Mercado Asegurador A...  Gran Buenos Aires
# 15  <p>Nos encontramos en búsqueda de un  Ingenier...  Gran Buenos Aires
# 16  <p><strong>Estamos en busqueda de representant...  Gran Buenos Aires
# 17  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 18  <p>SC Johnson, empresa líder mundial en fabric...  Gran Buenos Aires
# 19  <p>Centro Médico Accord se encuentra en la bús...  Gran Buenos Aires
# 20  <p>Nos encontramos en la búsqueda de un Analis...  Gran Buenos Aires
# 21  <p>Importante correo privado ubicado en SAN MI...  Gran Buenos Aires
# 22  <p><strong>Express se encuentra en la búsqueda...  Gran Buenos Aires
# 23  <p style="">Concesionario Oficial Renault Nº1 ...  Gran Buenos Aires
# 24  <p>Si te gusta deleitar a tus clientes, brinda...    Capital Federal
# 25  <p style=""><span style="">Somos una empresa a...  Gran Buenos Aires
# 26  <p><strong>Descripción del aviso de empleo:</s...  Gran Buenos Aires
# 27  <p>Somos una empresa 100% argentina que se esp...  Gran Buenos Aires
# 28  <p>Nos encontramos en la busqueda de chofer  d...  Gran Buenos Aires
# 29  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
#
#              ciudad               mapacalle tipo_de_trabajo  \
# 0               NaN                     NaN       Full-time
# 1               NaN                     NaN       Full-time
# 2               NaN          Empedrado 2336       Full-time
# 3               NaN                     NaN       Full-time
# 4               NaN                     NaN       Full-time
# 5               NaN                     NaN       Full-time
# 6               NaN                     NaN       Full-time
# 7               NaN                     NaN       Full-time
# 8      Buenos Aires                     NaN       Full-time
# 9               NaN                     NaN       Full-time
# 10              NaN                     NaN       Full-time
# 11              NaN                     NaN       Full-time
# 12              NaN                     NaN       Full-time
# 13              NaN                     NaN       Full-time
# 14  Capital Federal                     NaN       Full-time
# 15              NaN                     NaN       Full-time
# 16              NaN                     NaN       Part-time
# 17              NaN                     NaN       Full-time
# 18              NaN                     NaN       Full-time
# 19              NaN                     NaN       Full-time
# 20              NaN                     NaN       Full-time
# 21              NaN                     NaN       Full-time
# 22              NaN                     NaN       Full-time
# 23              NaN                     NaN       Full-time
# 24              NaN  Gobernador Irigoyen 56       Full-time
# 25              NaN                     NaN       Full-time
# 26              NaN                     NaN       Full-time
# 27              NaN                     NaN       Full-time
# 28              NaN                     NaN       Full-time
# 29              NaN                     NaN       Full-time
#
#                       nivel_laboral                          nombre_area  \
# 0              Senior / Semi-Senior                            Comercial
# 1              Senior / Semi-Senior                                Salud
# 2              Senior / Semi-Senior                           Transporte
# 3              Senior / Semi-Senior                           Transporte
# 4              Senior / Semi-Senior                           Producción
# 5              Senior / Semi-Senior                               Ventas
# 6              Senior / Semi-Senior                               Ventas
# 7                            Junior                               Ventas
# 8   Jefe / Supervisor / Responsable                            Comercial
# 9                              Otro                  Atención al Cliente
# 10             Senior / Semi-Senior                                Salud
# 11             Senior / Semi-Senior                               Ventas
# 12             Senior / Semi-Senior                               Ventas
# 13             Senior / Semi-Senior                        Mantenimiento
# 14             Senior / Semi-Senior                            Comercial
# 15             Senior / Semi-Senior  Ingeniería  Eléctrica y Electrónica
# 16             Senior / Semi-Senior                            Comercial
# 17             Senior / Semi-Senior                               Ventas
# 18             Senior / Semi-Senior                       Abastecimiento
# 19                           Junior                       Administración
# 20                           Junior                         Contabilidad
# 21                           Junior                         Distribución
# 22                             Otro                                Redes
# 23             Senior / Semi-Senior                               Ventas
# 24             Senior / Semi-Senior                            Comercial
# 25             Senior / Semi-Senior                      Soporte Técnico
# 26             Senior / Semi-Senior                           Producción
# 27             Senior / Semi-Senior                              Calidad
# 28             Senior / Semi-Senior                            Comercial
# 29             Senior / Semi-Senior                Oficios y Profesiones
#
#                  denominacion_empresa
# 0                              VENTOR
# 1             Farmacias Central Oeste
# 2                         FAMITAX SRL
# 3                 Wurth Argentina S.A
# 4                  ELECTRO OUTLET SRL
# 5                 Wurth Argentina S.A
# 6                 Wurth Argentina S.A
# 7                 Wurth Argentina S.A
# 8   Agencia Oficial Alejandro Arizaga
# 9                           cerantola
# 10                  Hochschild Mining
# 11                Wurth Argentina S.A
# 12                         YAMANIL SA
# 13              Adecco -Región Office
# 14           Romasanta y Asociados SA
# 15                     Bairestron SRL
# 16                     Directway S.A.
# 17                Wurth Argentina S.A
# 18      SC Johnson & Son de Argentina
# 19                     Unión Personal
# 20                       Motomel S.A.
# 21                     Asoko Tempo SA
# 22                    TELEDIFUSORA SA
# 23                       RENAULT DIAZ
# 24                    RE/MAX TITANIUM
# 25               Grupo Pujol Figueras
# 26                             VENTOR
# 27                       Food Service
# 28   Nini Centro de Compras Mayorista
# 29                Wurth Argentina S.A

# %% [markdown]
# # tamanio de los dataframe

# %%
print("Postulantes Educacion: " + str(postulantes_educacion.shape))

print("Postulantes Genero y Edad: " + str(postulantes_genero_y_edad.shape))

print("Vistas: " + str(vistas.shape))

print("Postulaciones: " + str(postulaciones.shape))

print("Avisos Online: " + str(avisos_online.shape))

print("Avisos Detalle: " + str(avisos_detalle.shape))
# Out:
# Postulantes Educacion: (298231, 3)
# Postulantes Genero y Edad: (200888, 3)
# Vistas: (961897, 3)
# Postulaciones: (3401623, 3)
# Avisos Online: (5028, 1)
# Avisos Detalle: (13534, 11)

# %% [markdown]
# # Cantidad por valores de columna

# %%
postulantes_educacion['nombre'].value_counts()
#postulantes_genero_y_edad['anioNacimiento'] = postulantes_genero_y_edad['fechanacimiento'].apply(lambda x: x.split('-')[0])
# Out:
# Secundario           110256
# Universitario        104295
# Terciario/Técnico     47733
# Otro                  24748
# Posgrado               7387
# Master                 3598
# Doctorado               214
# Name: nombre, dtype: int64

# %%
postulantes_educacion['estado'].value_counts()
#postulantes_genero_y_edad['anioNacimiento'] = po
# Out:
# Graduado      194474
# En Curso       78531
# Abandonado     25226
# Name: estado, dtype: int64

# %%
#le sumo la xolumna edad por q viene la fecha de nacimiento y no la edad especifica
postulantes_genero_y_edad['edad'] =  2018 - postulantes_genero_y_edad[postulantes_genero_y_edad['fechanacimiento'].notnull()]['fechanacimiento'].apply(lambda x: x.split('-')[0]).apply(np.int64)
#aca no me dejaba convertir la col edad de float a int por los nan's asii q converti los nana a 0 y conveti toda la col en int
postulantes_genero_y_edad['edad'] = postulantes_genero_y_edad['edad'].fillna(0.0).apply(np.int64)
#saque los valores ridiculos
edades = postulantes_genero_y_edad[(postulantes_genero_y_edad['edad'] > 17) & (postulantes_genero_y_edad['edad'] < 100)]['edad'].value_counts().sort_index(ascending=False)

# %%
postulantes_genero_y_edad
# Out:
#        idpostulante fechanacimiento        sexo  edad
# 0              NM5M      1970-12-03         FEM    48
# 1              5awk      1962-12-04         FEM    56
# 2              ZaO5      1978-08-10         FEM    40
# 3              NdJl      1969-05-09        MASC    49
# 4              eo2p      1981-02-16        MASC    37
# 5              Ez8J      1968-12-18        MASC    50
# 6              aOQq      1966-07-16        MASC    52
# 7              8BkL      1976-07-21         FEM    42
# 8              1d2B      1976-02-28        MASC    42
# 9              NPBx      1981-03-09        MASC    37
# 10             NRE5      1973-02-13        MASC    45
# 11             YGBY      1963-04-09         FEM    55
# 12             6aGl      1967-01-30         FEM    51
# 13             EbVz      1977-07-16        MASC    41
# 14             EBO0      1973-09-11         FEM    45
# 15             10bb      1954-08-30        MASC    64
# 16             eWO2      1959-01-05        MASC    59
# 17             6Kbl      1976-09-03        MASC    42
# 18             Ym2X      1964-01-19        MASC    54
# 19             ZqWb      1971-11-08        MASC    47
# 20             ZKl5      1974-05-06        MASC    44
# 21             eBAB      1963-03-10        MASC    55
# 22             N2Vx      1966-05-30        MASC    52
# 23            EDD99      1966-03-01         FEM    52
# 24            ED0l4      1969-07-17        MASC    49
# 25            NAMRl      1976-01-25        MASC    42
# 26            Y0Q2Z      1966-06-29        MASC    52
# 27            ZjDRz      1967-06-04        MASC    51
# 28            Y043Z      1979-03-24        MASC    39
# 29            eRpw9      1972-06-29        MASC    46
# ...             ...             ...         ...   ...
# 200858      GNZqARp      1982-04-15        MASC    36
# 200859      vVja48E      1977-04-06         FEM    41
# 200860      A3X4Em6      1998-10-02         FEM    20
# 200861      QNrBoJz      1996-07-08         FEM    22
# 200862      LNKp0ap      1988-01-01        MASC    30
# 200863      rmdlBE9      1994-03-02        MASC    24
# 200864      GNZqA2p      1995-07-05         FEM    23
# 200865      ow2p8vk      1990-03-21         FEM    28
# 200866      akjVl35      1990-08-25         FEM    28
# 200867      6rPEvwv      1997-07-22        MASC    21
# 200868      vVja45X      1996-04-26        MASC    22
# 200869      xkd65wV      1988-08-26         FEM    30
# 200870      X95JX3Q             NaN  NO_DECLARA     0
# 200871      mzdNo99      1999-08-10         FEM    19
# 200872      Nzr1J34             NaN  NO_DECLARA     0
# 200873      JBrNMNk      1997-01-11        MASC    21
# 200874      Ezem8m6      1993-02-19        MASC    25
# 200875      A3X4E41      1994-07-26         FEM    24
# 200876      mzdNorY             NaN         FEM     0
# 200877      PmGP9vJ      1992-11-29         FEM    26
# 200878      GNZqAaE      1997-07-08         FEM    21
# 200879      6rPEvzO             NaN  NO_DECLARA     0
# 200880      ow2p8Z0             NaN  NO_DECLARA     0
# 200881      vVja4x5      1997-06-23        MASC    21
# 200882      6rPEver      1997-04-22        MASC    21
# 200883      1QPMbX3      1988-01-07        MASC    30
# 200884      0zPa0eq      1998-05-09         FEM    20
# 200885      2zP6Jd0      1997-03-06         FEM    21
# 200886      8MPoxDW      1997-07-07        MASC    21
# 200887      2zP6J9V             NaN  NO_DECLARA     0
#
# [200888 rows x 4 columns]

# %%
# %matplotlib notebook
edades.plot(kind='barh',figsize=(10,10),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel('cantidad de postulantes',fontsize=15);
ax.set_xlabel('edad de postulante',fontsize=15)
ax.set_title('Cantidad de postulantes por edad',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'Cantidad de postulantes por edad')

# %%
# %matplotlib notebook

postulantes_genero_y_edad['sexo'].value_counts().plot(kind='bar',figsize=(10,5),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel('sexo',fontsize=10);
ax.set_xlabel('cantidad por sexo',fontsize=10)
ax.set_title('Cantidad de postulantes por sexo',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'Cantidad de postulantes por sexo')

# %%
postulantes_genero_y_edad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200888 entries, 0 to 200887
# Data columns (total 4 columns):
# idpostulante       200888 non-null object
# fechanacimiento    196138 non-null object
# sexo               200888 non-null object
# edad               200888 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 6.1+ MB

# %%
postulantes_genero_y_edad['het_map'] = 1
for_hetmap1 = postulantes_genero_y_edad[((postulantes_genero_y_edad['sexo']=='FEM') | (postulantes_genero_y_edad['sexo']=='MASC'))& (postulantes_genero_y_edad['edad']<100)]
for_hetmap1 = for_hetmap1.pivot_table(index='sexo', columns='edad', values='het_map', aggfunc='sum')
for_hetmap1
# Out:
# edad     0    12     18      19      20      21      22      23      24  \
# sexo
# FEM   304.0  NaN  352.0  2210.0  3741.0  4937.0  5775.0  6330.0  6520.0
# MASC  323.0  1.0  229.0  1431.0  2708.0  3556.0  4153.0  4551.0  5021.0
#
# edad      25 ...     69   70   71   72   74   75   76   77   79   97
# sexo         ...
# FEM   6704.0 ...    1.0  5.0  3.0  NaN  NaN  NaN  1.0  NaN  NaN  1.0
# MASC  4994.0 ...   10.0  4.0  4.0  2.0  3.0  2.0  2.0  1.0  1.0  NaN
#
# [2 rows x 63 columns]

# %%
# %matplotlib notebook
g = sns.heatmap(for_hetmap1, linewidths=.5, cmap="YlGnBu",  xticklabels = 2,cbar_kws={"orientation": "horizontal"} )
ax=plt.gca()
ax.set_title('Cantidad de postulantes por edad y sexo',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# Text(0.5,1,'Cantidad de postulantes por edad y sexo')

# %%
postulantes_educacion['het_map'] = 1
for_hetmap2 = postulantes_educacion.pivot_table(index='estado', columns='nombre', values='het_map', aggfunc='sum')
for_hetmap2
# Out:
# nombre      Doctorado  Master   Otro  Posgrado  Secundario  Terciario/Técnico  \
# estado
# Abandonado         15     144    947       317        3156               5692
# En Curso           94    1519   4919      2239        3995              15032
# Graduado          105    1935  18882      4831      103105              27009
#
# nombre      Universitario
# estado
# Abandonado          14955
# En Curso            50733
# Graduado            38607

# %%
# %matplotlib notebook
g = sns.heatmap(for_hetmap2, linewidths=.5, cmap="YlGnBu")
ax=plt.gca()
ax.set_title('Cantidad de postulantes por estudio y estado del mismo',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# Text(0.5,1,'Cantidad de postulantes por estudio y estado del mismo')

# %%
avisos_detalle['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires              12654
# Capital Federal                  876
# Buenos Aires (fuera de GBA)        2
# GBA Oeste                          2
# Name: nombre_zona, dtype: int64

# %%
# %matplotlib notebook
avisos_detalle['nombre_zona'].value_counts().plot(kind='bar',figsize=(10,5),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel('cantidad de publicaciones',fontsize=12);
ax.set_xlabel('zona',fontsize=12)
ax.set_title('Cantidad de publicaciones por zona',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'Cantidad de publicaciones por zona')

# %%
avisos_detalle['ciudad'].value_counts()
# Out:
# Buenos Aires                14
# Argentina                   13
# CABA                         3
# San Isidro                   2
# Capital Federal              2
# República Argentina          1
# Parque Patricios             1
# Tortuguitas                  1
# Microcentro                  1
# Santa Rosa                   1
# caba                         1
# paternal                     1
# Zárate, Campana, Escobar     1
# Vicente Lopez                1
# La Plata                     1
# Barracas                     1
# Buenos Aires Province        1
# Mendoza                      1
# Name: ciudad, dtype: int64

# %%
# %matplotlib notebook
avisos_detalle['ciudad'].value_counts().plot(kind='barh',figsize=(13,4),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_title('Cantidad de publicaciones por ciudad',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1300">
# Text(0.5,1,'Cantidad de publicaciones por ciudad')

# %%
avisos_detalle['tipo_de_trabajo'].value_counts()
# Out:
# Full-time          12339
# Part-time            863
# Teletrabajo          110
# Pasantia              63
# Por Horas             63
# Temporario            42
# Por Contrato          37
# Fines de Semana       14
# Primer empleo          3
# Name: tipo_de_trabajo, dtype: int64

# %%
# %matplotlib notebook
avisos_detalle['tipo_de_trabajo'].value_counts().plot(kind='barh',figsize=(10,4),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_title('Cantidad de publicaciones por tipo de trabajo',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# Text(0.5,1,'Cantidad de publicaciones por tipo de trabajo')

# %%
avisos_detalle['nivel_laboral'].value_counts()
# Out:
# Senior / Semi-Senior                    9407
# Junior                                  2216
# Otro                                     921
# Jefe / Supervisor / Responsable          809
# Gerencia / Alta Gerencia / Dirección     181
# Name: nivel_laboral, dtype: int64

# %%
avisos_detalle['nivel_laboral'].value_counts().plot(kind='barh',figsize=(12,4),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_title('Cantidad de publicaciones por nivel de trabajo',fontsize=25)
# Out:
# Text(0.5,1,'Cantidad de publicaciones por nivel de trabajo')

# %%
avisos_detalle['nombre_area'].value_counts()
# Out:
# Ventas                                   1659
# Comercial                                 983
# Administración                            901
# Producción                                821
# Programación                              576
# Contabilidad                              416
# Tecnologia / Sistemas                     388
# Atención al Cliente                       347
# Mantenimiento                             324
# Recursos Humanos                          235
# Gastronomia                               234
# Oficios y Profesiones                     209
# Soporte Técnico                           203
# Logística                                 200
# Call Center                               191
# Almacén / Depósito / Expedición           184
# Compras                                   170
# Marketing                                 153
# Otros                                     153
# Administración de Personal                152
# Recepcionista                             151
# Transporte                                148
# Mantenimiento y Limpieza                  141
# Finanzas                                  138
# Telemarketing                             138
# Tesorería                                 137
# Créditos y Cobranzas                      132
# Salud                                     127
# Desarrollo de Negocios                    126
# Medicina                                  119
#                                          ...
# Investigación y Desarrollo                  3
# Instrumentación                             2
# Dirección                                   2
# Mercadotecnia Internacional                 2
# Diseño 3D                                   2
# Educación especial                          2
# Trabajo Social                              2
# Trabajo social                              2
# Otras áreas técnicas en salud               2
# Medicina Laboral                            2
# Diseño Multimedia                           2
# Farmacia comercial                          2
# Data Warehousing                            2
# Ingeniería Geológica                        2
# Responsabilidad Social                      2
# Topografía                                  2
# Telefonista                                 1
# Arte y Cultura                              1
# Otras Especialidades médicas                1
# Quimica                                     1
# Comunicaciones Externas                     1
# Ingeniería en Petróleo y Petroquímica       1
# Urbanismo                                   1
# Farmacia hospitalaria                       1
# Bienestar Estudiantil                       1
# Instrumentación quirúrgica                  1
# Traduccion                                  1
# Idiomas                                     1
# Exploración Minera y Petroquimica           1
# Emergentología                              1
# Name: nombre_area, Length: 173, dtype: int64

# %%
# %matplotlib notebook
#saco los valores menores a 20 por que afectan en la visu
porAreas = avisos_detalle.groupby('nombre_area')['idaviso'].describe()
#porAreas = porAreas[porAreas['count']>20]
porAreas.sort_values(ascending = False, by = 'count').head(10)['count'].plot(kind='barh',figsize=(14,13),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel("Area de trabajo",fontsize= 10)
ax.set_xlabel("Cantidad de publicaciones",fontsize = 10)
ax.set_title('Top 10 de mayor cantidad \n de publicaciones por area de trabajo',fontsize=22)
# Out:
# <img src="data:image/png;base64,..." width="1400">
# Text(0.5,1,'Top 10 de mayor cantidad \n de publicaciones por area de trabajo')

# %%
# %matplotlib notebook
#saco los valores menores a 20 por que afectan en la visu
porAreas = avisos_detalle.groupby('nombre_area')['idaviso'].describe()
porAreas = porAreas[porAreas['count']>10]
porAreas.sort_values(ascending = True, by = 'count').head(10)['count'].plot(kind='barh',figsize=(14,13),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel("Area de trabajo",fontsize= 10)
ax.set_xlabel("Cantidad de publicaciones",fontsize = 10)
ax.set_title('Top 10 de menor cantidad \n de publicaciones por area de trabajo',fontsize=22)
# Out:
# <img src="data:image/png;base64,..." width="1400">
# Text(0.5,1,'Top 10 de menor cantidad \n de publicaciones por area de trabajo')

# %%
postulaciones
# Out:
#             idaviso idpostulante     fechapostulacion
# 0        1112257047         NM5M  2018-01-15 16:22:34
# 1        1111920714         NM5M  2018-02-06 09:04:50
# 2        1112346945         NM5M  2018-02-22 09:04:47
# 3        1112345547         NM5M  2018-02-22 09:04:59
# 4        1112237522         5awk  2018-01-25 18:55:03
# 5        1112277633         5awk  2018-01-29 13:34:44
# 6        1112302347         5awk  2018-02-07 20:49:22
# 7        1112291495         5awk  2018-02-07 20:50:13
# 8        1112304011         5awk  2018-02-07 20:51:15
# 9        1112326289         5awk  2018-02-09 20:24:57
# 10       1112303543         5awk  2018-02-18 23:49:34
# 11       1112315393         5awk  2018-02-19 00:01:20
# 12       1112315188         5awk  2018-02-28 15:54:28
# 13       1112346738         5awk  2018-02-28 15:54:47
# 14       1112330625         5awk  2018-02-28 15:56:43
# 15       1112306543         5awk  2018-02-28 15:57:35
# 16       1112315170         5awk  2018-02-28 15:59:14
# 17       1111799928         5awk  2018-02-28 16:00:06
# 18       1112323355         5awk  2018-02-28 16:00:41
# 19       1112305358         5awk  2018-02-28 16:02:15
# 20       1112286523         ZaO5  2018-01-24 15:07:39
# 21       1112272060         ZaO5  2018-01-24 15:20:10
# 22       1112288401         ZaO5  2018-01-26 08:37:04
# 23       1112300563         ZaO5  2018-01-30 13:35:48
# 24       1112293018         ZaO5  2018-01-31 08:41:05
# 25       1112301287         ZaO5  2018-01-31 08:55:20
# 26       1112309589         ZaO5  2018-02-03 15:55:15
# 27       1112317020         ZaO5  2018-02-07 09:56:22
# 28       1112322363         ZaO5  2018-02-09 10:29:54
# 29       1112327122         ZaO5  2018-02-11 17:49:26
# ...             ...          ...                  ...
# 3401593  1112345347      PmGP9vJ  2018-02-28 23:52:11
# 3401594  1112357658      PmGP9vJ  2018-02-28 23:58:12
# 3401595  1112368250      GNZqAaE  2018-02-28 23:18:45
# 3401596  1112368750      GNZqAaE  2018-02-28 23:24:13
# 3401597  1111413600      GNZqAaE  2018-02-28 23:25:09
# 3401598  1112348533      6rPEvzO  2018-02-28 23:27:25
# 3401599  1112369306      ow2p8Z0  2018-02-28 23:23:36
# 3401600  1112367705      ow2p8Z0  2018-02-28 23:23:57
# 3401601  1112366909      ow2p8Z0  2018-02-28 23:26:49
# 3401602  1112349451      vVja4x5  2018-02-28 23:27:05
# 3401603  1112318545      vVja4x5  2018-02-28 23:28:08
# 3401604  1112354215      vVja4x5  2018-02-28 23:42:56
# 3401605  1112368214      6rPEver  2018-02-28 23:54:35
# 3401606  1112349559      6rPEver  2018-02-28 23:56:19
# 3401607  1112165615      6rPEver  2018-02-28 23:57:03
# 3401608  1112369739      1QPMbX3  2018-02-28 23:41:51
# 3401609  1111732991      1QPMbX3  2018-02-28 23:45:56
# 3401610  1112350030      1QPMbX3  2018-02-28 23:47:27
# 3401611  1112366913      1QPMbX3  2018-02-28 23:48:49
# 3401612  1112366611      1QPMbX3  2018-02-28 23:50:42
# 3401613  1112334662      1QPMbX3  2018-02-28 23:56:53
# 3401614  1112354320      1QPMbX3  2018-02-28 23:57:22
# 3401615  1112360579      1QPMbX3  2018-02-28 23:58:32
# 3401616  1112359520      1QPMbX3  2018-02-28 23:59:34
# 3401617  1112344822      0zPa0eq  2018-02-28 23:49:46
# 3401618  1111753681      0zPa0eq  2018-02-28 23:54:44
# 3401619  1112369306      2zP6Jd0  2018-02-28 23:57:43
# 3401620  1112308651      8MPoxDW  2018-02-28 23:52:13
# 3401621  1112341128      8MPoxDW  2018-02-28 23:59:06
# 3401622  1112369825      2zP6J9V  2018-02-28 23:56:10
#
# [3401623 rows x 3 columns]

# %% [raw]
# ¿Como varía la cantidad de postulaciones segun los mes del año?

# %%
import calendar
postulaciones.dropna(subset=['fechapostulacion'],inplace=True)
postulaciones['fechapostulacion'] = pd.to_datetime(postulaciones['fechapostulacion'])
postulaciones['Month'] = postulaciones['fechapostulacion'].map(lambda x:x.month)

# %%
postulaciones['Month'].value_counts()
postulaciones.sort_values().head()
postulaciones['Year']= postulaciones['fechapostulacion'].map(lambda x:x.year)
postulaciones['Year'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-328-16575acf586a> in <module>()
#       1 postulaciones['Month'].value_counts()
# ----> 2 postulaciones.sort_values().head()
#       3 postulaciones['Year']= postulaciones['fechapostulacion'].map(lambda x:x.year)
#       4 postulaciones['Year'].value_counts()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
# %matplotlib notebook
postulaciones['Month'].value_counts().plot(kind='barh',figsize=(10,4),rot=0,fontsize= 8,grid = True);
label = ["Febrero","Enero"]
ax=plt.gca()
ax.set_yticklabels(label)
ax.set_xlabel("cantidad",fontsize=15)
ax.set_ylabel("mes",fontsize=15)
ax.set_title('Cantidad de postulaciones segun el mes del anio',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'Cantidad de postulaciones segun el mes del anio')

# %%
def func(x):
    if x <= 500:
        return 1
    elif x >500 and x <= 1000:
        return 2
    elif x >1500 and x <= 2500:
        return 3
    elif x >2500 and x <= 5000:
        return 4
    elif x > 5000:
        return 5

avisos_detalle['descripcion_lenght'] = avisos_detalle['descripcion'].str.len()
avisos_detalle["lenght_category"] = avisos_detalle["descripcion_lenght"].apply(lambda x: func(x))

# %%
avisos_detalle.set_index('idaviso')
# Out:
#             idpais                                             titulo  \
# idaviso
# 8725750          1                   VENDEDOR/A PROVINCIA DE SANTA FE
# 17903700         1                                         Enfermeras
# 1000150677       1                                     Chofer de taxi
# 1000610287       1      CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 1000872556       1      Operarios de Planta - Rubro Electrodomésticos
# 1001135716       1      Vendedor Viajante TUCUMAN/SANTIAGO DEL ESTERO
# 1001326344       1           Vendedor Viajante RECONQUISTA/AVELLANEDA
# 1001455648       1            Vendedor Viajante PILAR / ESCOBAR/TIGRE
# 9240880          1  Productores Asesores Independiente, para venta...
# 1001202662       1                              promotor/a , asesor/a
# 1001724563       1                                         Paramédico
# 1002181678       1                 Vendedor Viajante TIERRA DEL FUEGO
# 1002308544       1   Preventistas Importante Distribuidora de Bebidas
# 1002377536       1  Personal con experiencia en lavandería  para H...
# 1002448818       1                           Ejecutivo de Cuentas Sr.
# 1002511855       1                                Ingeniero Electrico
# 1110319893       1                Vendedores Telefónicos (Part- time)
# 1110383223       1  Vendedor Viajante ADROGUE/LANUS/AVELLANEDA/LOM...
# 1110386791       1                        Analista de Demand Planning
# 1110185164       1                        Administrativo de Recepción
# 1110322236       1                                  Analista Contable
# 1110513885       1    Distribuidor domiciliario con moto (SAN MIGUEL)
# 1110322853       1            OPERADOR para Centro Operaciones de Red
# 1110640369       1                     VENDEDORES DE PLANES DE AHORRO
# 1110640622       1  Agente Inmobiliario para Oficinas RE/MAX en Zo...
# 1110706074       1         TECNICO SSr.  -Soporte a usuarios nivel 2-
# 1110711023       1   ENVASADOR / PREPARADOR / CONTROLADOR / EMBALADOR
# 1110715814       1                      Jefe de Calidad con movilidad
# 1110843329       1                                Chofer para Reparto
# 1110906170       1         SUPERVISOR COMODORO RIVADAVIA/BAHIA BLANCA
# ...            ...                                                ...
# 1112342117       1         Programador C# .NET Sr. // Zona Tribunales
# 1112342134       1                   Electricista para Barrio Cerrado
# 1112342203       1              Analista en Sistemas y Desarrollo Web
# 1112342204       1  Ejecutivo de Ventas - Prov. de Bs. As e Interi...
# 1112342210       1                                 Licenciado en RRHH
# 1112342213       1                        Programadores Oracle PL/SQL
# 1112342246       1                    Analista Funcional - zona Pilar
# 1112342264       1  Analista de liquidación de Sueldos Senior  Co...
# 1112342289       1     Ingeniero Ssr para logística interna de partes
# 1112342347       1  Operario con exp. en Inyección plástica Z/ Lom...
# 1  <p>En Randstad Argentina nos encontramos en bú...  Gran Buenos Aires
# 2  <p style="">4 Finance, importante empresa fina...  Gran Buenos Aires
# 3  <p>En Randstad Argentina nos encontramos en bú...  Gran Buenos Aires
# 4  <p>Para Empresa Pyme ubicada en zona de Barrac...  Gran Buenos Aires
#
#   ciudad mapacalle tipo_de_trabajo         nivel_laboral          nombre_area  \
# 0    NaN       NaN       Part-time                  Otro  Atención al Cliente
# 1    NaN       NaN       Part-time  Senior / Semi-Senior        Telemarketing
# 2    NaN       NaN       Full-time  Senior / Semi-Senior        Telemarketing
# 3    NaN       NaN       Full-time  Senior / Semi-Senior        Telemarketing
# 4    NaN       NaN       Full-time  Senior / Semi-Senior         Contabilidad
#
#                        denominacion_empresa  descripcion_lenght  \
# 0                    Eficasia Argentina SA               2419.0
# 1                                  RANDSTAD              1216.0
# 2                            Prestamo Movil               970.0
# 3                                  RANDSTAD               751.0
# 4  SPEEDWORK RRHH - #1 en Selección de RRHH               780.0
#
#    lenght_category
# 0              3.0
# 1              NaN
# 2              2.0
# 3              2.0
# 4              2.0

# %%
postulacionesyavisosdetalle["lenght_category"].value_counts()
# Out:
# 2.0    1116998
# 3.0     465580
# 1.0     402298
# 4.0     282584
# 5.0      14876
# Name: lenght_category, dtype: int64

# %%
a = avisos_detalle["lenght_category"].value_counts()
a = a.to_frame()
a
# Out:
#      lenght_category
# 2.0             4396
# 3.0             2537
# 1.0             1743
# 4.0             1443
# 5.0               98

# %%
b = postulacionesyavisosdetalle["lenght_category"].value_counts()
b = b.to_frame()
b
# Out:
#      lenght_category
# 2.0          1116998
# 3.0           465580
# 1.0           402298
# 4.0           282584
# 5.0            14876

# %%
c = pd.merge(a,b, left_index=True, right_index=True)
c['cant_postulaciones'] = c['lenght_category_y']/c['lenght_category_x']
c.head()
# Out:
#      lenght_category_x  lenght_category_y  cant_postulaciones
# 2.0               4396            1116998          254.094177
# 3.0               2537             465580          183.515964
# 1.0               1743             402298          230.807803
# 4.0               1443             282584          195.830908
# 5.0                 98              14876          151.795918

# %%
# %matplotlib notebook
c['promedio_de_postulaciones'] = c['cant_postulaciones']
c.plot(kind='barh',figsize=(13,4),rot=0,fontsize= 8,grid = True,y='promedio_de_postulaciones');
ax=plt.gca()
y_labels=["largo de 500 a 1500","largo de 1500 a 2500","largo menor a 500","largo de 2500 a 500","largo mayor a 5000"]
ax.set_yticklabels(y_labels)
ax.set_xlabel("promedio", fontsize =10)
ax.set_title('Promedio de postulaciones segun el largo de la descripcion',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1300">
# Text(0.5,1,'Promedio de postulaciones segun el largo de la descripcion')

# %%
postulaciones.shape
# Out:
# (3401623, 4)

# %%
postulantes_educacion.shape
# Out:
# (298231, 3)

# %%
#Solo tengo en cuenta los postulantes que solo tienen un nivel de estuduio

postulantes_1_estudio = postulantes_educacion.drop_duplicates(subset='idpostulante',keep=False)
postulantes_1_estudio.shape
# Out:
# (108476, 3)

# %%
x = pd.merge(postulaciones,postulantes_1_estudio,how ='inner',on = 'idpostulante' )
x.shape
# Out:
# (1706904, 6)

# %%
# %matplotlib notebook
x['nombre'].value_counts().plot(kind='barh',figsize=(13,4),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_xlabel("cantidad", fontsize =10)
ax.set_ylabel("tipo de estudio", fontsize =10)
ax.set_title('Cantidad de postulaciones por tipo de estudio',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1300">
# Text(0.5,1,'Cantidad de postulaciones por tipo de estudio')

# %%
# %matplotlib notebook
x['het_map'] = 1
for_hetmap3 = x.pivot_table(index='estado', columns='nombre', values='het_map', aggfunc='sum')

g = sns.heatmap(for_hetmap3, linewidths=.5, cmap="YlGnBu",cbar_kws={"orientation": "horizontal"} )
ax=plt.gca()
ax.set_title('Cantidad de postulaciones por tipo de estudio',fontsize=20)
#ax.set_yticklabels([1,2,3] )
# Out:
# <img src="data:image/png;base64,..." width="1500">
# Text(0.5,1,'Cantidad de postulaciones por tipo de estudio')

# %%
people_data = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'people_name': ['People A', 'People B', 'People C', 'People D', 'People E'],
}

q = pd.DataFrame(people_data, columns = ['subject_id', 'people_name'])
q
# Out:
#   subject_id people_name
# 0          1    People A
# 1          2    People B
# 2          3    People C
# 3          4    People D
# 4          5    People E

# %%
subject_data = {
        'subject_id': ['1', '2','2','200'],
        'subject_name': ['Subject 1', 'Subject 2','Subject 2b', 'Subject 200'],
}
w = pd.DataFrame(subject_data, columns = ['subject_id', 'subject_name'])
w
# Out:
#   subject_id subject_name
# 0          1    Subject 1
# 1          2    Subject 2
# 2          2   Subject 2b
# 3        200  Subject 200

# %%
pd.merge(q,w,how = 'inner', on = 'subject_id')
# Out:
#   subject_id people_name subject_name
# 0          1    People A    Subject 1
# 1          2    People B    Subject 2
# 2          2    People B   Subject 2b

# %%
pd.merge(q,w,how = 'outer', on = 'subject_id')
# Out:
#   subject_id people_name subject_name
# 0          1    People A    Subject 1
# 1          2    People B    Subject 2
# 2          2    People B   Subject 2b
# 3          3    People C          NaN
# 4          4    People D          NaN
# 5          5    People E          NaN
# 6        200         NaN  Subject 200

# %%
pd.merge(q,w,how = 'left', on = 'subject_id')
# Out:
#   subject_id people_name subject_name
# 0          1    People A    Subject 1
# 1          2    People B    Subject 2
# 2          2    People B   Subject 2b
# 3          3    People C          NaN
# 4          4    People D          NaN
# 5          5    People E          NaN

# %%
pd.merge(q,w,how = 'right', on = 'subject_id')
# Out:
#   subject_id people_name subject_name
# 0          1    People A    Subject 1
# 1          2    People B    Subject 2
# 2          2    People B   Subject 2b
# 3        200         NaN  Subject 200

# %%
empresas = avisos_detalle['denominacion_empresa'].value_counts().sort_values(ascending = False).head(10)
empresas
# Out:
# RANDSTAD                              562
# Manpower                              422
# Grupo Gestión                         383
# Assistem                              289
# SOLUTIX S.A.                          260
# BAYTON                                238
# Pullmen Servicios Empresarios S.A.    229
# Adecco - Región NORTE & OESTE GBA     205
# Suministra                            203
# Adecco -Región Office                 200
# Name: denominacion_empresa, dtype: int64

# %%
# %matplotlib notebook
empresas.plot(kind='barh',figsize=(8,5),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel('Empresa',fontsize=15);
ax.set_xlabel('cantidad',fontsize=15)
ax.set_title('Cantidad de publicaciones por empresa',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'Cantidad de publicaciones por empresa')

# %% [markdown]
# # #Se toma las postulaciones de personas que estan estudiando

# %%
postulaciones_detalle = pd.merge(postulaciones, postulantes_educacion, on='idpostulante', how='left')

enCurso = (postulaciones_detalle['estado']=='En Curso')

postulaciones_estudiantes = postulaciones_detalle[enCurso]

postulaciones_estudiantes.head()
# Out:
#        idaviso idpostulante    fechapostulacion  Month    nombre    estado
# 82  1112261212         NdJl 2018-01-16 08:50:30      1  Posgrado  En Curso
# 84  1112273308         NdJl 2018-01-23 07:53:47      1  Posgrado  En Curso
# 86  1112281548         NdJl 2018-01-24 05:10:12      1  Posgrado  En Curso
# 88  1112260409         NdJl 2018-01-24 05:17:29      1  Posgrado  En Curso
# 90  1112293547         NdJl 2018-01-29 15:41:43      1  Posgrado  En Curso

# %%
# %matplotlib notebook
total = pd.merge(postulaciones_estudiantes, avisos_detalle, on='idaviso', how='left')

total = total[~pd.isnull(total['tipo_de_trabajo'])]
total

grupo = total.groupby('tipo_de_trabajo').agg({'tipo_de_trabajo':'count'}).sort_values('tipo_de_trabajo', ascending = False).head(3)
grupo.plot(kind='bar', figsize=(8,6),rot=0, fontsize= 12,grid = False)
ax=plt.gca()
ax.set_ylabel('cantidad de postulaciones',fontsize=12);
ax.set_xlabel('categorias',fontsize=12)
ax.set_title('Cantidad de postulaciones de estudiantes por tipo de trabajo ',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'Cantidad de postulaciones de estudiantes por tipo de trabajo ')

# %% [markdown]
# # Areas con mayor cantidad de postulaciones por genero

# %%
#Mergeo postulaciones con postulantes
postulaciones_postulantes = postulantes_genero_y_edad.merge(postulaciones,on=['idpostulante','idpostulante'])
#Mergeo lo anterior con el detalle de las postulaciones
postulaciones_detalle_postulantes = postulaciones_postulantes.merge(avisos_detalle, on=['idaviso','idaviso'])

#Obtengo los registros por genero
postulaciones_hombres = postulaciones_detalle_postulantes[postulaciones_detalle_postulantes['sexo'] == 'MASC']
postulaciones_mujeres = postulaciones_detalle_postulantes[postulaciones_detalle_postulantes['sexo'] == 'FEM']

# %%
postulaciones_detalle_postulantes['nombre_area'].value_counts().head()
# Out:
# Ventas                 408148
# Administración         291135
# Producción             277089
# Comercial              216677
# Atención al Cliente    195636
# Name: nombre_area, dtype: int64

# %%
postulaciones_por_categoria_y_genero = postulaciones_detalle_postulantes[['nombre_area', 'sexo']]
postulaciones_por_categoria_y_genero['hombre'] =  postulaciones_por_categoria_y_genero['sexo'] == 'MASC'
postulaciones_por_categoria_y_genero['mujer'] =  postulaciones_por_categoria_y_genero['sexo'] == 'FEM'
# Out:
# C:\Users\Pc\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Pc\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
postulaciones_por_categoria_y_genero = postulaciones_por_categoria_y_genero.groupby('nombre_area').agg({'hombre': np.sum, 'mujer': np.sum})
postulaciones_por_categoria_y_genero['total'] = postulaciones_por_categoria_y_genero['hombre'] + postulaciones_por_categoria_y_genero['mujer']

# %%
# %matplotlib notebook
postulaciones_por_categoria_y_genero.sort_values('total', ascending = False).head(6).plot(y=['hombre', 'mujer'], kind='bar', rot=0)
ax=plt.gca()
ax.set_ylabel('cantidad de postulaciones',fontsize=12);
ax.set_xlabel('categorias',fontsize=12)
ax.set_title('Cantidad de postulaciones por principales categorias',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# Text(0.5,1,'Cantidad de postulaciones por principales categorias')

# %%
vistas['idAviso'].value_counts()
# Out:
# 1112363488    4169
# 1112359836    4120
# 1112352317    4003
# 1112366909    3669
# 1112355872    3472
# 1112344973    3299
# 1112369306    3236
# 1112346591    2979
# 1112345900    2841
# 1112334791    2817
# 1112364849    2768
# 1112359880    2659
# 1112316288    2638
# 1112354099    2609
# 1112200601    2532
# 1112340866    2517
# 1112337868    2467
# 1112349037    2444
# 1112361693    2436
# 1112206678    2396
# 1112364754    2376
# 1112361175    2309
# 1112347174    2274
# 1112361527    2274
# 1112366913    2250
# 1112360679    2211
# 1112363083    2201
# 1112359300    2175
# 1112351629    2160
# 1112368053    2064
#               ...
# 1112279512       1
# 1112342094       1
# 1112278050       1
# 1112087794       1
# 1112341811       1
# 1111884027       1
# 1112226998       1
# 1111649574       1
# 1112159383       1
# 1112105024       1
# 1112206182       1
# 17903700         1
# 1111786490       1
# 1112296027       1
# 1112341750       1
# 1111496554       1
# 1112239042       1
# 1111263480       1
# 1112131226       1
# 1112249371       1
# 1111267132       1
# 1111645593       1
# 1112268758       1
# 1111930116       1
# 1111822280       1
# 1111722207       1
# 1112043828       1
# 1112144621       1
# 1112296400       1
# 1111501585       1
# Name: idAviso, Length: 7458, dtype: int64

# %%
cantidad_postulaciones = pd.DataFrame(postulaciones['idaviso'].value_counts().reset_index())
cantidad_postulaciones = cantidad_postulaciones.rename(columns = {'index' : 'idaviso','idaviso':'cantidad_de_postulaciones'})
cantidad_postulaciones.shape
# Out:
# (12692, 2)

# %%
cantidad_visitas = pd.DataFrame(vistas['idAviso'].value_counts().reset_index())
cantidad_visitas = cantidad_visitas.rename(columns = {'index' : 'idaviso','idAviso':'cantidad_de_visitas'})
cantidad_visitas.shape
# Out:
# (7458, 2)

# %%
visitas_postulaciones = pd.merge(cantidad_visitas,cantidad_postulaciones,how= 'left',left_on='idaviso',right_on='idaviso')
visitas_postulaciones.shape
# Out:
# (7458, 3)

# %%
visitas_postulaciones = visitas_postulaciones.fillna(0)

# %%
# %matplotlib notebook
top = visitas_postulaciones[visitas_postulaciones['cantidad_de_postulaciones'] == 0 ].sort_values(by = 'cantidad_de_visitas',ascending = False).head(10).set_index('idaviso')
top['cantidad_de_visitas'].plot(kind='barh',figsize=(8,5),rot=0,fontsize= 8,grid = True);
ax=plt.gca()
ax.set_ylabel('ID aviso',fontsize=15);
ax.set_xlabel('cantidad de vistas ',fontsize=15)
ax.set_title('Top 10 de avisos vistos pero no postulado',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'Top 10 de avisos vistos pero no postulado')

# %%
postulantes_educacion_sin_repetidos = postulantes_educacion.drop_duplicates(subset='idpostulante',keep = False)
postulantes1 = pd.merge(postulantes_educacion_sin_repetidos,postulantes_genero_y_edad,how='inner',left_on = 'idpostulante',right_on = 'idpostulante')
postulantes1
# Out:
#        idpostulante             nombre      estado fechanacimiento  \
# 0              1d2B      Universitario    En Curso      1976-02-28
# 1             6M3jr      Universitario    En Curso      1975-11-03
# 2             EpDDJ      Universitario    En Curso      1961-11-28
# 3             ex4j2      Universitario    En Curso      1975-10-21
# 4             ZPWlE      Universitario    En Curso      1962-05-18
# 5             NrlQx  Terciario/Técnico    En Curso      1973-09-23
# 6             eaXOE      Universitario    En Curso      1975-04-11
# 7             aBeQZ  Terciario/Técnico    En Curso      1967-03-08
# 8             8V5RW      Universitario    En Curso      1972-11-19
# 9             aBL4W      Universitario    En Curso      1976-01-04
# 10            8k92x      Universitario    En Curso      1965-01-19
# 11            Y9RKV      Universitario    En Curso      1982-09-29
# 12            ZL608      Universitario    En Curso      1978-04-28
# 13            Nw8zx      Universitario    En Curso      1978-08-31
# 14            ZLdN1      Universitario    En Curso      1980-01-22
# 15            EK0Kz      Universitario    En Curso      1982-04-10
# 16            aEW8J      Universitario    En Curso      1965-05-19
# 17            ZQGQY      Universitario    En Curso      1977-08-10
# 18            ao42J      Universitario    En Curso      1968-01-03
# 19            eA4mB      Universitario    En Curso      1975-07-01
# 20            ZYqMZ      Universitario    En Curso      1969-12-13
# 21            1Kd9N      Universitario    En Curso      1977-09-13
# 22           1lWaJB      Universitario    En Curso      1980-03-27
# 23           a6Oea0      Universitario    En Curso      1979-11-20
# 24           a6joV9  Terciario/Técnico    En Curso      1979-03-28
# 25           EDkkZo      Universitario    En Curso      1969-01-25
# 26           52QElN      Universitario    En Curso      1981-08-02
# 27           8w8EXW  Terciario/Técnico    En Curso      1979-10-16
# 28           Y0MORw      Universitario    En Curso      1978-08-21
# 29           1lGQr3      Universitario    En Curso      1977-10-21
# ...             ...                ...         ...             ...
# 108446      8MPoLQM         Secundario  Abandonado      1966-05-27
# 108447      LNKp4Lq         Secundario  Abandonado      1996-03-09
# 108448      dYj4zPY      Universitario  Abandonado      1997-03-27
# 108449      Nzr1PdD               Otro  Abandonado      1988-01-11
# 108450      PmGPLJZ         Secundario  Abandonado      1980-02-27
# 108451      rmdl2Z6      Universitario  Abandonado      1987-12-29
# 108452      6rPEZY4      Universitario  Abandonado      1973-10-27
# 108453      OqrlPoW      Universitario  Abandonado      1994-01-22
# 108454      RzrQPb1         Secundario  Abandonado      1992-02-19
# 108455      xkd6aEa      Universitario  Abandonado             NaN
g = sns.heatmap(postulantes1_hetmap3, linewidths=.1,  xticklabels = 2, cmap="YlGnBu",cbar_kws={"orientation": "vertical"} )
ax=plt.gca()
ax.set_title('Cantidad de postulantes por edad y nivel de estudio',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1056">
# Text(0.5,1,'Cantidad de postulaciones por tipo de estudio')

# %%
# %matplotlib notebook
z2 = postulantes1[postulantes1['edad'] < 100]
postulantes1_hetmap3 = z2.pivot_table(index='estado', columns='edad', values='het_map', aggfunc='sum')

g = sns.heatmap(postulantes1_hetmap3, linewidths=.1,  xticklabels = 2, cmap="YlGnBu",cbar_kws={"orientation": "vertical"} )
ax=plt.gca()
ax.set_title('Cantidad de postulantes por edad y nivel de estudio',fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'Cantidad de postulantes por edad y nivel de estudio')

# %%
vistas['fecha'] = vistas['timestamp'].apply(lambda x: x.split('T')[0])
vistas['hora'] = vistas['timestamp'].apply(lambda x: x.split('.')[0]).apply(lambda x: x.split('T')[1])
vistas
# Out:
#            idAviso                     timestamp idpostulante       fecha  \
# 0       1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z  2018-02-23
# 1       1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR  2018-02-23
# 2       1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd  2018-02-23
# 3       1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv  2018-02-23
# 4       1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP  2018-02-23
# 5       1112355613  2018-02-23T13:38:23.467-0500      rmdWApz  2018-02-23
# 6       1112346704  2018-02-23T13:38:27.130-0500      Dr6e6Xl  2018-02-23
# 7       1112282610  2018-02-23T13:38:27.670-0500      A3R9GWl  2018-02-23
# 8       1112342544  2018-02-23T13:38:31.601-0500      8M24rbM  2018-02-23
# 9       1112358408  2018-02-23T13:38:32.977-0500      YjrD1ZZ  2018-02-23
# 10      1112350129  2018-02-23T13:38:33.441-0500       NGAjYL  2018-02-23
# 11      1112335938  2018-02-23T13:38:39.226-0500      0zdM4Ad  2018-02-23
# 12      1112343977  2018-02-23T13:38:40.951-0500      X95NQrO  2018-02-23
# 13      1112341619  2018-02-23T13:38:45.390-0500      GNdYAQp  2018-02-23
# 14      1112358408  2018-02-23T13:38:48.716-0500      YjrD1ZZ  2018-02-23
# 15      1112356639  2018-02-23T13:38:51.739-0500      BmVpYoR  2018-02-23
# 16      1112056879  2018-02-23T13:38:52.770-0500      qe24j4x  2018-02-23
# 17      1112357772  2018-02-23T13:38:58.432-0500      wVOlZpl  2018-02-23
# 18      1112348302  2018-02-23T13:38:59.868-0500      vVj16rj  2018-02-23
# 19      1112339122  2018-02-23T13:39:00.980-0500      MV6VXJe  2018-02-23
# 20      1112323190  2018-02-23T13:39:01.985-0500      1QdrA8b  2018-02-23
# 21      1112348933  2018-02-23T13:39:02.632-0500      A3vYzYL  2018-02-23
# 3401618  1111753681      0zPa0eq  2018-02-28 23:54:44      2  2018-02-28
# 3401619  1112369306      2zP6Jd0  2018-02-28 23:57:43      2  2018-02-28
# 3401620  1112308651      8MPoxDW  2018-02-28 23:52:13      2  2018-02-28
# 3401621  1112341128      8MPoxDW  2018-02-28 23:59:06      2  2018-02-28
# 3401622  1112369825      2zP6J9V  2018-02-28 23:56:10      2  2018-02-28
#
#              hora
# 0        16:22:34
# 1        09:04:50
# 2        09:04:47
# 3        09:04:59
# 4        18:55:03
# 5        13:34:44
# 6        20:49:22
# 7        20:50:13
# 8        20:51:15
# 9        20:24:57
# 10       23:49:34
# 11       00:01:20
# 12       15:54:28
# 13       15:54:47
# 14       15:56:43
# 15       15:57:35
# 16       15:59:14
# 17       16:00:06
# 18       16:00:41
# 19       16:02:15
# 20       15:07:39
# 21       15:20:10
# 22       08:37:04
# 23       13:35:48
# 24       08:41:05
# 25       08:55:20
# 26       15:55:15
# 27       09:56:22
# 28       10:29:54
# 29       17:49:26
# ...           ...
# 3401593  23:52:11
# 3401594  23:58:12
# 3401595  23:18:45
# 3401596  23:24:13
# 3401597  23:25:09
# 3401598  23:27:25
# 3401599  23:23:36
# 3401600  23:23:57
# 3401601  23:26:49
# 3401602  23:27:05
# 3401603  23:28:08
# 3401604  23:42:56
# 3401605  23:54:35
# 3401606  23:56:19
# 3401607  23:57:03
# 3401608  23:41:51
# 3401609  23:45:56
# 3401610  23:47:27
# 3401611  23:48:49
# 3401612  23:50:42
# 3401613  23:56:53
# 3401614  23:57:22
# 3401615  23:58:32
# 3401616  23:59:34
# 3401617  23:49:46
# 3401618  23:54:44
# 3401619  23:57:43
# 3401620  23:52:13
# 3401621  23:59:06
# 3401622  23:56:10
#
# [3401623 rows x 6 columns]

# %%
def hora(x):
    if x < 6 and x>=0:
        return "madrugada"
    elif x >=6 and x <= 12:
        return "mañana"
    elif x >12 and x <=18:
        return "tarde"
    elif x >18 and x <  24:
        return "noche"

# %%
vistas['turno'] = vistas['hora'].apply(lambda x: x.split(':')[0]).astype(int).apply(lambda x : hora(x))
postulaciones['turno'] = postulaciones['hora'].apply(lambda x: x.split(':')[0]).astype(int).apply(lambda x : hora(x))

# %%
# %matplotlib notebook
vistas['turno'].value_counts().plot(kind='bar', figsize=(8,6),rot=0, fontsize= 12,grid = False)
ax=plt.gca()
ax.set_ylabel('cantidad de visistas',fontsize=12);
ax.set_xlabel('horario',fontsize=12)
ax.set_title('Cantidad de visitas para cada horario ',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'Cantidad de visitas para cada horario ')

# %%
# %matplotlib notebook
postulaciones['turno'].value_counts().plot(kind='bar', figsize=(8,6),rot=0, fontsize= 12,grid = False)
ax=plt.gca()
ax.set_ylabel('cantidad de postulaciones',fontsize=12);
ax.set_xlabel('horario',fontsize=12)
ax.set_title('Cantidad de postulaciones para cada horario ',fontsize=25)
# Out:
# <img src="data:image/png;base64,..." width="875">
# Text(0.5,1,'Cantidad de postulaciones para cada horario ')
