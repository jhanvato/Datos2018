# %%
import datetime as datetime
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor

# %%
nba = pd.read_csv("nba_2013.csv", low_memory=False)

# %%
nba.head(10)
# Out:
#               player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0         Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1       Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2        Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3      Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4      Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
# 5       Cole Aldrich   C   25          NYK  46   2   330   33    61  0.541
# 6  LaMarcus Aldridge  PF   28          POR  69  69  2498  652  1423  0.458
# 7        Lavoy Allen  PF   24          TOT  65   2  1072  134   300  0.447
# 8          Ray Allen  SG   38          MIA  73   9  1936  240   543  0.442
# 9         Tony Allen  SG   32          MEM  55  28  1278  204   413  0.494
#
#       ...      drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# ...

# %%
#Limpieza de datos

distance_columns = ['age', 'g', 'gs', 'mp', 'fg', 'fga', 'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft', 'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts']
# Solo columnas numericas
nba_numeric = nba[distance_columns]

# Normalize all of the numeric columns
nba_normalized = (nba_numeric - nba_numeric.mean()) / nba_numeric.std()


nba_normalized.fillna(0, inplace=True)

# %%
x_columns = ['age', 'g', 'gs', 'mp', 'fg', 'fga', 'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft', 'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf']
y_column = ["pts"]

# %%
# Creo una instalncia del algoritmo que va a buscar a los 5 vecinos mas cercanos
knn = KNeighborsRegressor(n_neighbors=5)

# %%
# Le ingreso la informacion al algoritmo
nba.fillna(0, inplace=True)
knn.fit(nba[x_columns], nba[y_column])
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
# Pruebo el algoritmo con el set de entrenamiento MUY MAL, pero es en forma de ejemplo!!!
predictions = knn.predict(nba[x_columns])

# %%
predictions
# Out:
# array([[  1.63600000e+02],
#        [  2.61600000e+02],
#        [  3.57000000e+02],
#        [  1.24560000e+03],
#        [  3.25200000e+02],
#        [  8.76000000e+01],
#        [  1.62260000e+03],
#        [  3.54200000e+02],
#        [  5.85000000e+02],
#        [  4.80200000e+02],
#        [  6.73000000e+02],
#        [  3.92000000e+01],
#        [  4.69400000e+02],
#        [  5.26000000e+02],
#        [  8.09000000e+02],
#        [  3.12400000e+02],
#        [  5.49400000e+02],
#        [  2.06440000e+03],
#        [  3.26000000e+01],
#        [  3.40600000e+02],
#        [  1.13500000e+03],
#        [  2.40000000e+01],
#        [  4.16400000e+02],
#        [  2.78000000e+02],
#        [  8.76600000e+02],
#        [  1.29400000e+02],
#        [  2.22400000e+02],
#        [  2.92000000e+01],
#        [  1.92400000e+02],
#        [  1.50800000e+02],
#        [  7.02600000e+02],
#        [  4.83800000e+02],
#        [  7.57600000e+02],
#        [  5.96600000e+02],
# ...
